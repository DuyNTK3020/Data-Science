# %% [markdown]
# # Introduction to Seaborn

# %%
# import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import warnings
# warnings.filterwarnings("ignore", message="use_inf_as_na option is deprecated", category=FutureWarning)

# %%
# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %% [markdown]
# ### Styling

# %%
sns.set_theme()

# %% [markdown]
# ## Numerical Plots
# - **Distribution**: Hist, KDE, displot
# - **Bar Plot**
# - **Count Plot**
# - **Facet Plot**: Tạo ra một lướt 2D gồm các bảng được xác định bởi các biến tạo thành các hàng và cột
# - **Box Plot**: Phương pháp để mô tả bằng đồ thị các nhóm dữ liệu số thông qua các phần tư của chúng
# - **Join Plot**
# - **Pair Plot**
# - **Heat Map**: Một kỹ thuật trực quan hóa dữ liệu cho thấy cường độ của một hiện tượng là màu sắc ở 2 chiều

# %% [markdown]
# ### Distribution Plot
# - Univariate distribution of observations

# %%
tips_df = sns.load_dataset('tips')

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data=tips_df["total_bill"]);

# %%
tips_df["total_bill"].value_counts().sort_values(ascending=False)
# Out:
# total_bill
# 13.42    3
# 7.25     2
# 21.01    2
# 20.69    2
# 10.34    2
#         ..
# 29.03    1
# 27.18    1
# 22.67    1
# 17.82    1
# 18.78    1
# Name: count, Length: 229, dtype: int64

# %% [markdown]
# ## KDE Plot
# * A kenrnel density estimate (KDE) plot is a method for visuallizing the distribution of observarions in a dataset, analagous to a histogram.
# * KDE represents the data using a continuous probability densiry curve in one or more dimensions

# %%
sns.kdeplot(data=tips_df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### Dis plot
# * Informative distributional summaries
# * Statistial analyses ...
# *

# %%
sns.displot(data=tips_df, x="total_bill", col="time", kde=True)
# Out:
# C:\Users\khanh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\khanh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(

# %% [markdown]
# ### Categorical Plots
# #### Bar Plots

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(data=tips_df, x = "sex", y = "tip", estimator = np.mean)
# Out:
# C:\Users\khanh\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# #### Count Plot

# %%
sns.countplot(data=tips_df, x = "sex")
# Out:
# C:\Users\khanh\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# #### Box Plot
# Box Plot is a good indicarion of how the values in the data ate spread out
# ....

# %%
sns.boxplot(data=tips_df, x = "day", y = "total_bill")
# Out:
# C:\Users\khanh\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips_df, x = "day", y = "total_bill", hue="sex", palette="Blues")
plt.legend(loc = 0)
# Out:
# C:\Users\khanh\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ### Facet Grid
# * FaceGrid can be drawn with up to three dimensions: row, col and hue
# * The main approach for visualizing data on this grid is with the FacetGrid.map() method

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_fg = sns.FacetGrid(data=tips_df, row="smoker", col="time") #Create a class instance of Facer Grid class
tips_fg.map(sns.scatterplot, 'total_bill', 'tip')

# %%
new_fg = sns.FacetGrid(data=tips_df, col="sex") 
new_fg.map(sns.scatterplot, 'total_bill', 'tip')
